# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
out = np.load("out.npy")
print(out.shape)
keypoint2d_maps = np.load("keypoint2d_maps.npy")
print(keypoint2d_maps.shape)
paf_maps = np.load("paf_maps.npy")
print(paf_maps.shape)
# Out:
# (57, 32, 48)
# (19, 32, 48)
# (38, 32, 48)

# %%
plt.imshow(out[20])

# %%
keypoint2d_maps[0]
# Out:
# array([[ 1.7363159e-03,  1.9204617e-04,  1.7878599e-04, ...,
#          2.8610602e-04,  1.0048784e-04,  1.0166876e-04],
#        [ 1.3195270e-02,  2.7763471e-04,  3.3590477e-04, ...,
#          2.9321108e-04,  1.9130763e-04,  1.2269802e-04],
#        [ 2.4685413e-03,  2.5702361e-04,  2.1557324e-04, ...,
#          1.5798677e-04,  2.2965670e-04,  2.1342933e-04],
#        ...,
#        [ 8.0939382e-05,  1.9746087e-04,  8.9361332e-05, ...,
#         -5.8963895e-05,  6.1543658e-05, -2.1032616e-04],
#        [ 1.8369220e-04,  2.8460845e-04,  2.9099546e-04, ...,
#          8.1117265e-05,  2.3181550e-05,  1.2568198e-05],
#        [ 2.0785164e-04,  2.2323709e-04,  1.1572521e-04, ...,
#          7.1589835e-05,  6.3078199e-04,  7.5572729e-04]], dtype=float32)

# %%
plt.imshow(keypoint2d_maps[18])

# %%
paf_maps[0]
# Out:
# array([[-1.9333015e-04,  2.4298820e-06, -4.8126356e-05, ...,
#          2.4298820e-06,  2.4298820e-06, -5.9764749e-05],
#        [ 2.4298820e-06,  2.4298820e-06,  2.4298820e-06, ...,
#          2.4298820e-06,  2.4298820e-06,  2.4298820e-06],
#        [ 2.4298820e-06, -7.4432297e-05,  2.4298820e-06, ...,
#          2.4298820e-06,  2.4298820e-06,  2.4298820e-06],
#        ...,
#        [ 2.4298820e-06,  2.4298820e-06,  2.4298820e-06, ...,
#          2.4298820e-06,  2.4298820e-06,  2.4298820e-06],
#        [-8.4301093e-05,  2.4298820e-06,  2.4298820e-06, ...,
#          2.4298820e-06,  2.4298820e-06, -1.0694957e-03],
#        [-2.7143471e-05,  2.4298820e-06,  2.4298820e-06, ...,
#          2.4298820e-06, -1.1064069e-04, -1.1297760e-03]], dtype=float32)

# %%
plt.imshow(paf_maps[1])
